# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_table('orange_small_train.data')

# %%
train.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10   ...    \
# 0   NaN   NaN   NaN   NaN   NaN  1526.0   7.0   NaN   NaN    NaN   ...
# 1   NaN   NaN   NaN   NaN   NaN   525.0   0.0   NaN   NaN    NaN   ...
# 2   NaN   NaN   NaN   NaN   NaN  5236.0   7.0   NaN   NaN    NaN   ...
# 3   NaN   NaN   NaN   NaN   NaN     NaN   0.0   NaN   NaN    NaN   ...
# 4   NaN   NaN   NaN   NaN   NaN  1029.0   7.0   NaN   NaN    NaN   ...
#
#     Var221   Var222      Var223  Var224  Var225  Var226   Var227  \
# 0     oslk  fXVEsaq  jySVZNlOJy     NaN     NaN    xb3V     RAYp
# 1     oslk  2Kb5FSF  LM8l689qOp     NaN     NaN    fKCe     RAYp
# 2  Al6ZaUT  NKv4yOc  jySVZNlOJy     NaN    kG3k    Qu4f  02N6s8f
# 3     oslk  CE7uk3u  LM8l689qOp     NaN     NaN    FSa2     RAYp
# 4     oslk  1J2cvxe  LM8l689qOp     NaN    kG3k    FSa2     RAYp
#
#           Var228  Var229  Var230
# 0  F2FyR07IdsN7I     NaN     NaN
# 1  F2FyR07IdsN7I     NaN     NaN
# 2  ib5G6X1eUxUn6    am7c     NaN
# 3  F2FyR07IdsN7I     NaN     NaN
# 4  F2FyR07IdsN7I    mj86     NaN
#
# [5 rows x 230 columns]

# %%
# Converting the labels as category variables
appetency = pd.read_table('appetency.txt', header = None).iloc[:,0].astype('category')

# %%
appetency.cat.rename_categories(['no', 'yes'], inplace = True)
appetency
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
# 5         no
# 6         no
# 7         no
# 8         no
# 9         no
# 10        no
# 11        no
# 12        no
# 13        no
# 14        no
# 15        no
# 16        no
# 17        no
# 18        no
# 19        no
# 20        no
# 21        no
# 22        no
# 23        no
# 24        no
# 25        no
# 26        no
# 27        no
# 28        no
# 29        no
#         ...
# 49970     no
# 49971    yes
# 49972    yes
# 49973     no
# 49974     no
# 49975     no
# 49976     no
# 49977     no
# 49978     no
# 49979     no
# 49980     no
# 49981     no
# 49982     no
# 49983     no
# 49984     no
# 49985     no
# 49986     no
# 49987     no
# 49988     no
# 49989     no
# 49990     no
# 49991     no
# 49992     no
# 49993     no
# 49994     no
# 49995    yes
# 49996    yes
# 49997     no
# 49998     no
# 49999     no
# Name: 0, Length: 50000, dtype: category
# Categories (2, object): [no, yes]

# %%
test = pd.read_table('orange_small_test.data')

# %%
test.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10   ...    \
# 0   NaN   NaN   NaN   NaN   NaN  1225.0   7.0   NaN   NaN    NaN   ...
# 1   NaN   NaN   NaN   NaN   NaN   259.0   0.0   NaN   NaN    NaN   ...
# 2   NaN   NaN   NaN   NaN   NaN   861.0  14.0   NaN   NaN    NaN   ...
# 3   NaN   NaN   NaN   NaN   NaN  1568.0   7.0   NaN   NaN    NaN   ...
# 4   NaN   NaN   NaN   NaN   NaN  1197.0   7.0   NaN   NaN    NaN   ...
#
#     Var221   Var222      Var223  Var224  Var225  Var226  Var227  \
# 0  Al6ZaUT  P6pu4Vl  LM8l689qOp     NaN    ELof    7P5s    ZI9m
# 1     oslk  S46Rt72  LM8l689qOp     NaN     NaN    Qu4f    RAYp
# 2     oslk  CcdTy9x  LM8l689qOp     NaN     NaN    7aLG    RAYp
# 3     oslk  Q53Rkup  LM8l689qOp     NaN    kG3k    7P5s    RAYp
# 4  Al6ZaUT  WfsWw2A  LM8l689qOp     NaN    ELof    5Acm    ZI9m
#
#                 Var228  Var229  Var230
# 0     R4y5gQQWY8OodqDV     NaN     NaN
# 1        F2FyR07IdsN7I     NaN     NaN
# 2        F2FyR07IdsN7I     NaN     NaN
# 3  TCU50_Yjmm6GIBZ0lL_    am7c     NaN
# 4           iyHGyLCEkQ    am7c     NaN
#
# [5 rows x 230 columns]

# %%
train.isnull().sum()
# Out:
# Var1      49298
# Var2      48759
# Var3      48760
# Var4      48421
# Var5      48513
# Var6       5529
# Var7       5539
# Var8      50000
# Var9      49298
# Var10     48513
# Var11     48760
# Var12     49442
# Var13      5539
# Var14     48760
# Var15     50000
# Var16     48513
# Var17     48421
# Var18     48421
# Var19     48421
# Var20     50000
# Var21      5529
# Var22      5009
# Var23     48513
# Var24      7230
# Var25      5009
# Var26     48513
# Var27     48513
# Var28      5011
# Var29     49298
# Var30     49298
#           ...
# Var201    37217
# Var202        1
# Var203      143
# Var204        0
# Var205     1934
# Var206     5529
# Var207        0
# Var208      143
# Var209    50000
# Var210        0
# Var211        0
# Var212        0
# Var213    48871
# Var214    25408
# Var215    49306
# Var216        0
# Var217      703
# Var218      703
# Var219     5211
# Var220        0
# Var221        0
# Var222        0
# Var223     5211
# Var224    49180
# Var225    26144
# Var226        0
# Var227        0
# Var228        0
# Var229    28432
# Var230    50000
# Length: 230, dtype: int64

# %%
train.describe()
# Out:
#              Var1         Var2           Var3         Var4          Var5  \
# count  702.000000  1241.000000    1240.000000  1579.000000  1.487000e+03
# mean    11.487179     0.004029     425.298387     0.125396  2.387933e+05
# std     40.709951     0.141933    4270.193518     1.275481  6.441259e+05
# min      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 25%      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 50%      0.000000     0.000000       0.000000     0.000000  0.000000e+00
# 75%     16.000000     0.000000       0.000000     0.000000  1.187425e+05
# max    680.000000     5.000000  130668.000000    27.000000  6.048550e+06
#
#                 Var6          Var7  Var8         Var9         Var10   ...    \
# count   44471.000000  44461.000000   0.0   702.000000  1.487000e+03   ...
# mean     1326.437116      6.809496   NaN    48.145299  3.926057e+05   ...
# std      2685.693668      6.326053   NaN   154.777855  9.280896e+05   ...
# min         0.000000      0.000000   NaN     0.000000  0.000000e+00   ...
# 25%       518.000000      0.000000   NaN     4.000000  0.000000e+00   ...
# 50%       861.000000      7.000000   NaN    20.000000  0.000000e+00   ...
# 75%      1428.000000      7.000000   NaN    46.000000  2.628630e+05   ...
# max    131761.000000    140.000000   NaN  2300.000000  1.232559e+07   ...
#
#              Var183       Var184  Var185      Var186     Var187       Var188  \
# count  1.241000e+03  1241.000000     0.0  702.000000  702.00000  1241.000000
# mean   7.777380e+04     8.460919     NaN    3.299145   16.54416   167.368477
# std    2.016188e+05    46.973777     NaN    8.781967   60.22303   113.980072
# min    0.000000e+00     0.000000     NaN    0.000000    0.00000    -6.420000
# 25%    0.000000e+00     0.000000     NaN    0.000000    0.00000    19.380000
# 50%    0.000000e+00     0.000000     NaN    0.000000    4.00000   197.640000
# 75%    4.881000e+04     8.000000     NaN    6.000000   14.00000   252.960000
# max    3.048400e+06  1200.000000     NaN  102.000000  910.00000   628.620000
#
#              Var189         Var190  Var209  Var230
# count  21022.000000     333.000000     0.0     0.0
# mean     270.142137   22007.045192     NaN     NaN
# std       86.707692   29085.146490     NaN     NaN
# min        6.000000       0.000000     NaN     NaN
# 25%      204.000000    2732.670000     NaN     NaN
# 50%      270.000000   12668.940000     NaN     NaN
# 75%      330.000000   29396.340000     NaN     NaN
# max      642.000000  230427.000000     NaN     NaN
#
# [8 rows x 192 columns]

# %%
train.dropna(axis = 1, how = 'all', inplace = True)

# %%
train.shape
# Out:
# (50000, 212)

# %%
#Plot number proportion of missing values
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
proportion_of_missing_values = train.isnull().sum()/train.shape[0]
plt.hist(proportion_of_missing_values)
# Out:
# (array([  28.,   38.,    1.,    0.,    2.,    5.,    0.,    2.,    0.,  136.]),
#  array([ 0.      ,  0.099658,  0.199316,  0.298974,  0.398632,  0.49829 ,
#          0.597948,  0.697606,  0.797264,  0.896922,  0.99658 ]),
#  <a list of 10 Patch objects>)

# %%
# print all variables with missing proportions < 0.5
x_vars = proportion_of_missing_values[proportion_of_missing_values <= 0.5].index
x_vars
# Out:
# Index(['Var6', 'Var7', 'Var13', 'Var21', 'Var22', 'Var24', 'Var25', 'Var28',
#        'Var35', 'Var38', 'Var44', 'Var57', 'Var65', 'Var72', 'Var73', 'Var74',
#        'Var76', 'Var78', 'Var81', 'Var83', 'Var85', 'Var94', 'Var109',
#        'Var112', 'Var113', 'Var119', 'Var123', 'Var125', 'Var126', 'Var132',
#        'Var133', 'Var134', 'Var140', 'Var143', 'Var144', 'Var149', 'Var153',
#        'Var160', 'Var163', 'Var173', 'Var181', 'Var192', 'Var193', 'Var195',
#        'Var196', 'Var197', 'Var198', 'Var199', 'Var202', 'Var203', 'Var204',
#        'Var205', 'Var206', 'Var207', 'Var208', 'Var210', 'Var211', 'Var212',
#        'Var216', 'Var217', 'Var218', 'Var219', 'Var220', 'Var221', 'Var222',
#        'Var223', 'Var226', 'Var227', 'Var228'],
#       dtype='object')

# %%
len(x_vars)
# Out:
# 69

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 212 entries, Var1 to Var229
# dtypes: float64(173), int64(1), object(38)
# memory usage: 80.9+ MB

# %%
# converting all int type into float and remaining into categorical
X_var_names = train.columns
for x_var in X_var_names:
    if train[x_var].dtype == int:
        x = train[x_var].astype(float)
        train.loc[:,x_var] = x
    elif train[x_var].dtype != float:
        x = train[x_var].astype('category')
        train.loc[:,x_var] = x
train.dtypes
# Out:
# Var1       float64
# Var2       float64
# Var3       float64
# Var4       float64
# Var5       float64
# Var6       float64
# Var7       float64
# Var9       float64
# Var10      float64
# Var11      float64
# Var12      float64
# Var13      float64
# Var14      float64
# Var16      float64
# Var17      float64
# Var18      float64
# Var19      float64
# Var21      float64
# Var22      float64
# Var23      float64
# Var24      float64
# Var25      float64
# Var26      float64
# Var27      float64
# Var28      float64
# Var29      float64
# Var30      float64
# Var33      float64
# Var34      float64
# Var35      float64
#             ...
# Var199    category
# Var200    category
# Var201    category
# Var202    category
# Var203    category
# Var204    category
# Var205    category
# Var206    category
# Var207    category
# Var208    category
# Var210    category
# Var211    category
# Var212    category
# Var213    category
# Var214    category
# Var215    category
# Var216    category
# Var217    category
# Var218    category
# Var219    category
# Var220    category
# Var221    category
# Var222    category
# Var223    category
# Var224    category
# Var225    category
# Var226    category
# Var227    category
# Var228    category
# Var229    category
# Length: 212, dtype: object

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 212 entries, Var1 to Var229
# dtypes: category(38), float64(174)
# memory usage: 72.0 MB

# %%
filling_mean = train.mean()
filling_mean
# Out:
# Var1      1.148718e+01
# Var2      4.029009e-03
# Var3      4.252984e+02
# Var4      1.253958e-01
# Var5      2.387933e+05
# Var6      1.326437e+03
# Var7      6.809496e+00
# Var9      4.814530e+01
# Var10     3.926057e+05
# Var11     8.625806e+00
# Var12     1.607168e+01
# Var13     1.249688e+03
# Var14     7.419355e-01
# Var16     1.202393e+02
# Var17     1.139329e+01
# Var18     7.215959e+00
# Var19     2.450918e-01
# Var21     2.345182e+02
# Var22     2.902454e+02
# Var23     7.535306e+00
# Var24     4.507926e+00
# Var25     9.682701e+01
# Var26     7.061197e-02
# Var27     2.824479e-02
# Var28     2.245077e+02
# Var29     2.279202e-02
# Var30     7.435897e+00
# Var33     1.270050e+05
# Var34     1.173247e+00
# Var35     7.168100e-01
#               ...
# Var157    3.307352e+01
# Var158    1.896907e+00
# Var159    4.713940e+00
# Var160    3.880301e+01
# Var161    3.374288e+00
# Var162    3.360168e+05
# Var163    4.860780e+05
# Var164    1.753642e+00
# Var165    2.884236e+04
# Var166    2.255346e+01
# Var168    3.329386e+02
# Var170    3.041096e+00
# Var171    3.674517e+05
# Var172    9.744452e+00
# Var173    6.845814e-03
# Var174    7.044965e+00
# Var176    4.716129e+00
# Var177    6.188884e+05
# Var178    1.668731e+01
# Var179    3.138062e+00
# Var180    3.776755e+06
# Var181    6.114556e-01
# Var182    1.416638e+06
# Var183    7.777380e+04
# Var184    8.460919e+00
# Var186    3.299145e+00
# Var187    1.654416e+01
# Var188    1.673685e+02
# Var189    2.701421e+02
# Var190    2.200705e+04
# Length: 174, dtype: float64

# %%
# Filling missing float column entries with their mean
filling_mean = train.mean()
for x_var in X_var_names:
    if train[x_var].dtype == float:
        if train[x_var].isnull().sum() > 0:
            train.loc[train[x_var].isnull().tolist(),x_var] = filling_mean[x_var]

# %%
train.shape
# Out:
# (50000, 212)

# %%
count = 0
for x_var in X_var_names:
    if train[x_var].dtype == float:
        count+=1
        print(x_var,':',train[x_var].isnull().sum())
print('Number of variables with float as datatype = ',count)
# Out:
# Var1 : 0
# Var2 : 0
# Var3 : 0
# Var4 : 0
# Var5 : 0
# Var6 : 0
# Var7 : 0
# Var9 : 0
# Var10 : 0
# Var11 : 0
# Var12 : 0
# Var13 : 0
# Var14 : 0
# Var16 : 0
# Var17 : 0
# Var18 : 0
# Var19 : 0
# Var21 : 0
# Var22 : 0
# Var23 : 0
# Var24 : 0
# Var25 : 0
# Var26 : 0
# Var27 : 0
# Var28 : 0
# Var29 : 0
# Var30 : 0
# Var33 : 0
# Var34 : 0
# Var35 : 0
# Var36 : 0
# Var37 : 0
# Var38 : 0
# Var40 : 0
# Var41 : 0
# Var43 : 0
# Var44 : 0
# Var45 : 0
# Var46 : 0
# Var47 : 0
# Var49 : 0
# Var50 : 0
# Var51 : 0
# Var53 : 0
# Var54 : 0
# Var56 : 0
# Var57 : 0
# Var58 : 0
# Var59 : 0
# Var60 : 0
# Var61 : 0
# Var62 : 0
# Var63 : 0
# Var64 : 0
# Var65 : 0
# Var66 : 0
# Var67 : 0
# Var68 : 0
# Var69 : 0
# Var70 : 0
# Var71 : 0
# Var72 : 0
# Var73 : 0
# Var74 : 0
# Var75 : 0
# Var76 : 0
# Var77 : 0
# Var78 : 0
# Var80 : 0
# Var81 : 0
# Var82 : 0
# Var83 : 0
# Var84 : 0
# Var85 : 0
# Var86 : 0
# Var87 : 0
# Var88 : 0
# Var89 : 0
# Var90 : 0
# Var91 : 0
# Var92 : 0
# Var93 : 0
# Var94 : 0
# Var95 : 0
# Var96 : 0
# Var97 : 0
# Var98 : 0
# Var99 : 0
# Var100 : 0
# Var101 : 0
# Var102 : 0
# Var103 : 0
# Var104 : 0
# Var105 : 0
# Var106 : 0
# Var107 : 0
# Var108 : 0
# Var109 : 0
# Var110 : 0
# Var111 : 0
# Var112 : 0
# Var113 : 0
# Var114 : 0
# Var115 : 0
# Var116 : 0
# Var117 : 0
# Var118 : 0
# Var119 : 0
# Var120 : 0
# Var121 : 0
# Var122 : 0
# Var123 : 0
# Var124 : 0
# Var125 : 0
# Var126 : 0
# Var127 : 0
# Var128 : 0
# Var129 : 0
# Var130 : 0
# Var131 : 0
# Var132 : 0
# Var133 : 0
# Var134 : 0
# Var135 : 0
# Var136 : 0
# Var137 : 0
# Var138 : 0
# Var139 : 0
# Var140 : 0
# Var142 : 0
# Var143 : 0
# Var144 : 0
# Var145 : 0
# Var146 : 0
# Var147 : 0
# Var148 : 0
# Var149 : 0
# Var150 : 0
# Var151 : 0
# Var152 : 0
# Var153 : 0
# Var154 : 0
# Var155 : 0
# Var156 : 0
# Var157 : 0
# Var158 : 0
# Var159 : 0
# Var160 : 0
# Var161 : 0
# Var162 : 0
# Var163 : 0
# Var164 : 0
# Var165 : 0
# Var166 : 0
# Var168 : 0
# Var170 : 0
# Var171 : 0
# Var172 : 0
# Var173 : 0
# Var174 : 0
# Var176 : 0
# Var177 : 0
# Var178 : 0
# Var179 : 0
# Var180 : 0
# Var181 : 0
# Var182 : 0
# Var183 : 0
# Var184 : 0
# Var186 : 0
# Var187 : 0
# Var188 : 0
# Var189 : 0
# Var190 : 0
# Number of variables with float as datatype =  174

# %%
# to describe all the columns we use include = 'all' as we have mixed type columns in our dataframe
train.describe(include = 'all')
# unique value for numeric datatype columns is displayed as NaN
# Out:
#                 Var1          Var2           Var3          Var4          Var5  \
# count   50000.000000  50000.000000   50000.000000  50000.000000  5.000000e+04
# unique           NaN           NaN            NaN           NaN           NaN
# top              NaN           NaN            NaN           NaN           NaN
# freq             NaN           NaN            NaN           NaN           NaN
# mean       11.487179      0.004029     425.298387      0.125396  2.387933e+05
# std         4.820354      0.022352     672.206258      0.226593  1.110451e+05
# min         0.000000      0.000000       0.000000      0.000000  0.000000e+00
# 25%        11.487179      0.004029     425.298387      0.125396  2.387933e+05
# 50%        11.487179      0.004029     425.298387      0.125396  2.387933e+05
# 75%        11.487179      0.004029     425.298387      0.125396  2.387933e+05
# max       680.000000      5.000000  130668.000000     27.000000  6.048550e+06
#
#                  Var6          Var7          Var9         Var10         Var11  \
# count    50000.000000  50000.000000  50000.000000  5.000000e+04  50000.000000
# unique            NaN           NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN           NaN
# mean      1326.437116      6.809496     48.145299  3.926057e+05      8.625806
# std       2532.849475      5.965363     18.326822  1.599995e+05      0.451721
# min          0.000000      0.000000      0.000000  0.000000e+00      8.000000
# 25%        581.000000      0.000000     48.145299  3.926057e+05      8.625806
# 50%        945.000000      7.000000     48.145299  3.926057e+05      8.625806
# 75%       1326.437116      7.000000     48.145299  3.926057e+05      8.625806
# max     131761.000000    140.000000   2300.000000  1.232559e+07     40.000000
#
#          ...     Var220  Var221   Var222      Var223  Var224  Var225  Var226  \
# count    ...      50000   50000    50000       44789     820   23856   50000
# unique   ...       4291       7     4291           4       1       3      23
# top      ...    4UxGlow    oslk  catzS2D  LM8l689qOp    4n2X    ELof    FSa2
# freq     ...       4441   37009     4441       36608     820   11072    8031
# mean     ...        NaN     NaN      NaN         NaN     NaN     NaN     NaN
# std      ...        NaN     NaN      NaN         NaN     NaN     NaN     NaN
# min      ...        NaN     NaN      NaN         NaN     NaN     NaN     NaN
# 25%      ...        NaN     NaN      NaN         NaN     NaN     NaN     NaN
# 50%      ...        NaN     NaN      NaN         NaN     NaN     NaN     NaN
# 75%      ...        NaN     NaN      NaN         NaN     NaN     NaN     NaN
# max      ...        NaN     NaN      NaN         NaN     NaN     NaN     NaN
#
#         Var227         Var228  Var229
# count    50000          50000   21568
# unique       7             30       4
# top       RAYp  F2FyR07IdsN7I    am7c
# freq     35156          32703   11689
# mean       NaN            NaN     NaN
# std        NaN            NaN     NaN
# min        NaN            NaN     NaN
# 25%        NaN            NaN     NaN
# 50%        NaN            NaN     NaN
# 75%        NaN            NaN     NaN
# max        NaN            NaN     NaN
#
# [11 rows x 212 columns]

# %%
# Cleaning categorical variables
# First let us list all categorical variables
categorical_var_names = [x_var_name for x_var_name in X_var_names if train[x_var_name].dtype != float]
# Number of categorical values per variable
categorical_var_levels = train[categorical_var_names].apply(lambda col : len(col.cat.categories))
categorical_var_levels
# Out:
# Var191        1
# Var192      361
# Var193       51
# Var194        3
# Var195       23
# Var196        4
# Var197      225
# Var198     4291
# Var199     5073
# Var200    15415
# Var201        2
# Var202     5713
# Var203        5
# Var204      100
# Var205        3
# Var206       21
# Var207       14
# Var208        2
# Var210        6
# Var211        2
# Var212       81
# Var213        1
# Var214    15415
# Var215        1
# Var216     2016
# Var217    13990
# Var218        2
# Var219       22
# Var220     4291
# Var221        7
# Var222     4291
# Var223        4
# Var224        1
# Var225        3
# Var226       23
# Var227        7
# Var228       30
# Var229        4
# dtype: int64

# %%
from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
test_proportion = .6
split = StratifiedShuffleSplit(
    y=appetency,
    n_iter=1,
    test_size=test_proportion,
    random_state=99)

for train_valid_indices, test_indices in split:
    X_train_valid, X_test = train.iloc[train_valid_indices, :], train.iloc[test_indices, :]
    appetency_train_valid, appetency_test = appetency.iloc[train_valid_indices], appetency.iloc[test_indices]
    
    
valid_proportion_of_train_valid = .25
split = StratifiedShuffleSplit(
    y=appetency_train_valid,
    n_iter=1,
    test_size=valid_proportion_of_train_valid,
    random_state=99)

for train_indices, valid_indices in split:
    X_train, X_valid = X_train_valid.iloc[train_indices, :], X_train_valid.iloc[valid_indices, :]
    appetency_train, appetency_valid = appetency_train_valid[train_indices], appetency_train_valid[valid_indices]

# %%
# Neglecting all variables with greater than 500 categories.

categorical_var_names = categorical_var_levels[categorical_var_levels <= 500].index

categorical_var_names
# Out:
# Index(['Var191', 'Var192', 'Var193', 'Var194', 'Var195', 'Var196', 'Var197',
#        'Var201', 'Var203', 'Var204', 'Var205', 'Var206', 'Var207', 'Var208',
#        'Var210', 'Var211', 'Var212', 'Var213', 'Var215', 'Var218', 'Var219',
#        'Var221', 'Var223', 'Var224', 'Var225', 'Var226', 'Var227', 'Var228',
#        'Var229'],
#       dtype='object')

# %% [markdown]
# #### For the remaining categorical variables, let's:
#
# #####    Make their missing values another category zzzMISSING
#
# ##### Try to consolidate the categories, as having too many categories make modeling less meaningful and numerically more difficult; for each variable, we'll collapse all categories with prevalence of under 5% together into a zzzOTHER category;
#
# #####    Drop categorical variables with only one category (obviously); and
#
# #####    Drop categorical variables with only one non-zzzMISSING category.

# %%
collapsed_categories = {}
removed_categorical_x_var_names = set()

for categorical_var_name in categorical_var_names:
  
    missing_value_row_yesno = X_train[categorical_var_name].isnull()
    if missing_value_row_yesno.sum() > 0:
        X_train[categorical_var_name].cat.add_categories('zzzMISSING', inplace=True)
        X_train.ix[missing_value_row_yesno.tolist(), categorical_var_name] = 'zzzMISSING'

    x = X_train[categorical_var_name].copy()
    for category in x.cat.categories:
        matching_rows_yesno = x == category
        if matching_rows_yesno.sum() < .05 * nb_train_samples:
            if categorical_var_name in collapsed_categories:
                collapsed_categories[categorical_var_name].append(category) 
            else:
                collapsed_categories[categorical_var_name] = [category]
            if 'zzzOTHER' not in X_train[categorical_var_name].cat.categories:
                X_train[categorical_var_name].cat.add_categories('zzzOTHER', inplace=True)
            X_train.ix[matching_rows_yesno, categorical_var_name] = 'zzzOTHER'
            X_train[categorical_var_name].cat.remove_categories(category, inplace=True)
  
    categories = X_train[categorical_var_name].cat.categories
    if (len(categories) == 1) or\
        (len(set(categories) - set(['zzzMISSING', 'zzzOTHER'])) < 2):
        removed_categorical_x_var_names.add(categorical_var_name)

categorical_var_names = list(set(categorical_var_names) - removed_categorical_x_var_names)
# Out:
# /home/suryavamsi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# /home/suryavamsi/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-30daf2af23c3> in <module>()
#      12     for category in x.cat.categories:
#      13         matching_rows_yesno = x == category
# ---> 14         if matching_rows_yesno.sum() < .05 * nb_train_samples:
#      15             if categorical_var_name in collapsed_categories:
#      16                 collapsed_categories[categorical_var_name].append(category)
#
# NameError: name 'nb_train_samples' is not defined
