# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
flight_train = pd.read_csv('flight_data_train.csv')
flight_train.sample(5)
# Out:
#       Day_Id  Spot1 maxDistance  Spot1 totalDistance  Spot1 totalFlights  \
# 753      801              83.09               614.95                   9
# 862      915               0.00                 0.00                   0
# 1450    1542               0.00                 0.00                   0
# 740      786               5.42                 5.42                   1
# 1001    1067               0.00                 0.00                   0
#
#       Spot2 maxDistance  Spot2 totalDistance  Spot2 totalFlights  \
# 753                 0.0                  0.0                   0
# 862                 0.0                  0.0                   0
# 1450                0.0                  0.0                   0
# 740                 0.0                  0.0                   0
# 1001                0.0                  0.0                   0
#
#       Spot3 maxDistance  Spot3 totalDistance  Spot3 totalFlights  \
# 753                 0.0                  0.0                   0
# ...

# %%
weather_train = pd.read_csv('weather_data_train.csv')
weather_train.sample(5)
# Out:
#       Day_Id  Station1 Dew Point Height1  Station1 Dew Point Height2  \
# 1856    1985                   12.541935                   12.265438
# 2082    2222                    8.675410                    9.003279
# 2059    2198                   15.678261                   16.570000
# 2105    2248                   13.013699                   12.882736
# 579      614                   16.232107                   15.830769
#
#       Station1 Dew Point Height3  Station1 Dew Point Height4  \
# 1856                   11.989262                   11.720805
# 2082                    9.331148                    8.573234
# 2059                   17.494262                   18.483333
# 2105                   12.752443                   12.622150
# 579                    15.429431                   15.028094
#
#       Station1 Dew Point Height5  Station1 Dew Point Height6  \
# 1856                   11.584786                   11.557123
# ...

# %%
weather_test = pd.read_csv('weather_data_test.csv')
weather_test.sample(5)
# Out:
#     Day_Id  Station1 Dew Point Height1  Station1 Dew Point Height2  \
# 29     697                    3.628936                    2.480000
# 8      230                    9.673846                   10.904615
# 98    2307                    5.302041                    4.485714
# 45    1033                    7.635200                    6.460606
# 36     894                   -1.152381                   -3.057143
#
#     Station1 Dew Point Height3  Station1 Dew Point Height4  \
# 29                    1.371984                    0.905058
# 8                    12.135385                   13.366154
# 98                    3.669388                    3.400000
# 45                    5.652525                    5.260392
# 36                   -4.961905                   -6.866667
#
#     Station1 Dew Point Height5  Station1 Dew Point Height6  \
# 29                    0.438132                   -0.026359
# 8                    14.339896                   15.272539
# ...
